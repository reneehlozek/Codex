# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data0=np.transpose(np.genfromtxt("OA44f.all1106.248480.txt",skip_header=4))
data1=np.transpose(np.genfromtxt("OA44f.all1106.248680.txt",skip_header=4))
data2=np.transpose(np.genfromtxt("OA44f.all1106.248900.txt",skip_header=4))
data3=np.transpose(np.genfromtxt("OA44f.all1106.249240p.txt",skip_header=4))
data4=np.transpose(np.genfromtxt("OA44f.all1106.249960p.txt",skip_header=4))
data5=np.transpose(np.genfromtxt("OA44f.all1106.250360.txt",skip_header=4))
data6=np.transpose(np.genfromtxt("OA44f.all1106.250400.txt",skip_header=4))
data7=np.transpose(np.genfromtxt("OA44f.all1106.250420.txt",skip_header=4))
data8=np.transpose(np.genfromtxt("OA44f.all1106.250440.txt",skip_header=4))
data9=np.transpose(np.genfromtxt("OA44f.all1106.250460.txt",skip_header=4))
data10=np.transpose(np.genfromtxt("OA44f.all1106.250640.txt",skip_header=4))
data11=np.transpose(np.genfromtxt("OA44f.all1106.250820.txt",skip_header=4))
data12=np.transpose(np.genfromtxt("OA44f.all1106.250980.txt",skip_header=4))
data13=np.transpose(np.genfromtxt("OA44f.all1106.251160p.txt",skip_header=4))

# %%
"""wave0=data0[0]
wave1=data1[0]
wave2=data2[0]
wave3=data3[0]
wave4=data4[0]
wave5=data5[0]
lumi0=data0[1]
lumi1=data1[1]
lumi2=data2[1]
lumi3=data3[1]
lumi4=data4[1]
lumi5=data5[1]"""
# Out:
# 'wave0=data0[0]\nwave1=data1[0]\nwave2=data2[0]\nwave3=data3[0]\nwave4=data4[0]\nwave5=data5[0]\nlumi0=data0[1]\nlumi1=data1[1]\nlumi2=data2[1]\nlumi3=data3[1]\nlumi4=data4[1]\nlumi5=data5[1]'

# %%
"""d=2.838e+20
#*1.828e+47
for i in range(len(wave0)):
    lumi0[i]=lumi0[i]*(wave0[i]/(4.0*np.pi*3.086e+20))
    lumi1[i]=lumi1[i]*(wave1[i]/(4.0*np.pi*3.086e+20))
    lumi2[i]=lumi2[i]*(wave2[i]/(4.0*np.pi*3.086e+20))
    lumi3[i]=lumi3[i]*(wave3[i]/(4.0*np.pi*3.086e+20))
    lumi4[i]=lumi4[i]*(wave4[i]/(4.0*np.pi*3.086e+20))
    lumi5[i]=lumi5[i]*(wave5[i]/(4.0*np.pi*3.086e+20))
    wave0[i]=wave0[i]*10000
    wave1[i]=wave1[i]*10000
    wave2[i]=wave2[i]*10000
    wave3[i]=wave3[i]*10000
    wave4[i]=wave4[i]*10000
    wave5[i]=wave5[i]*10000"""
# Out:
# 'd=2.838e+20\n#*1.828e+47\nfor i in range(len(wave0)):\n    lumi0[i]=lumi0[i]*(wave0[i]/(4.0*np.pi*3.086e+20))\n    lumi1[i]=lumi1[i]*(wave1[i]/(4.0*np.pi*3.086e+20))\n    lumi2[i]=lumi2[i]*(wave2[i]/(4.0*np.pi*3.086e+20))\n    lumi3[i]=lumi3[i]*(wave3[i]/(4.0*np.pi*3.086e+20))\n    lumi4[i]=lumi4[i]*(wave4[i]/(4.0*np.pi*3.086e+20))\n    lumi5[i]=lumi5[i]*(wave5[i]/(4.0*np.pi*3.086e+20))\n    wave0[i]=wave0[i]*10000\n    wave1[i]=wave1[i]*10000\n    wave2[i]=wave2[i]*10000\n    wave3[i]=wave3[i]*10000\n    wave4[i]=wave4[i]*10000\n    wave5[i]=wave5[i]*10000'

# %%
"""wave_cut0=np.zeros(5000)
wave_cut1=np.zeros(5000)
wave_cut2=np.zeros(5000)
wave_cut3=np.zeros(5000)
wave_cut4=np.zeros(5000)
wave_cut5=np.zeros(5000)
for j in range(5000):
    wave_cut0[j]=wave0[3*j]
    wave_cut1[j]=wave1[3*j]
    wave_cut2[j]=wave2[3*j]
    wave_cut3[j]=wave3[3*j]
    wave_cut4[j]=wave4[3*j]
    wave_cut5[j]=wave5[3*j]
    
lumi_cut0=np.zeros(5000)
lumi_cut1=np.zeros(5000)
lumi_cut2=np.zeros(5000)
lumi_cut3=np.zeros(5000)
lumi_cut4=np.zeros(5000)
lumi_cut5=np.zeros(5000)
for k in range(5000):
    lumi_cut0[k]=lumi0[3*k]
    lumi_cut1[k]=lumi1[3*k]
    lumi_cut2[k]=lumi2[3*k]
    lumi_cut3[k]=lumi3[3*k]
    lumi_cut4[k]=lumi4[3*k]
    lumi_cut5[k]=lumi5[3*k]"""
# Out:
# 'wave_cut0=np.zeros(5000)\nwave_cut1=np.zeros(5000)\nwave_cut2=np.zeros(5000)\nwave_cut3=np.zeros(5000)\nwave_cut4=np.zeros(5000)\nwave_cut5=np.zeros(5000)\nfor j in range(5000):\n    wave_cut0[j]=wave0[3*j]\n    wave_cut1[j]=wave1[3*j]\n    wave_cut2[j]=wave2[3*j]\n    wave_cut3[j]=wave3[3*j]\n    wave_cut4[j]=wave4[3*j]\n    wave_cut5[j]=wave5[3*j]\n    \nlumi_cut0=np.zeros(5000)\nlumi_cut1=np.zeros(5000)\nlumi_cut2=np.zeros(5000)\nlumi_cut3=np.zeros(5000)\nlumi_cut4=np.zeros(5000)\nlumi_cut5=np.zeros(5000)\nfor k in range(5000):\n    lumi_cut0[k]=lumi0[3*k]\n    lumi_cut1[k]=lumi1[3*k]\n    lumi_cut2[k]=lumi2[3*k]\n    lumi_cut3[k]=lumi3[3*k]\n    lumi_cut4[k]=lumi4[3*k]\n    lumi_cut5[k]=lumi5[3*k]'

# %%
"""time0=np.zeros(5000)
time1=np.zeros(5000)
time2=np.zeros(5000)
time3=np.zeros(5000)
time4=np.zeros(5000)
time5=np.zeros(5000)
for i in range(len(time0)):
    time0[i]=-90.0
    time1[i]=-60.0
    time2[i]=-30.0
    time3[i]=0.0
    time4[i]=30.0
    time5[i]=60.0"""
# Out:
# 'time0=np.zeros(5000)\ntime1=np.zeros(5000)\ntime2=np.zeros(5000)\ntime3=np.zeros(5000)\ntime4=np.zeros(5000)\ntime5=np.zeros(5000)\nfor i in range(len(time0)):\n    time0[i]=-90.0\n    time1[i]=-60.0\n    time2[i]=-30.0\n    time3[i]=0.0\n    time4[i]=30.0\n    time5[i]=60.0'

# %%
"""timed=np.hstack((time0,time1,time2,time3,time4,time5))
waved=np.hstack((wave_cut0,wave_cut1,wave_cut2,wave_cut3,wave_cut4,wave_cut5))
lumid=np.hstack((lumi_cut0,lumi_cut1,lumi_cut2,lumi_cut3,lumi_cut4,lumi_cut5))"""
# Out:
# 'timed=np.hstack((time0,time1,time2,time3,time4,time5))\nwaved=np.hstack((wave_cut0,wave_cut1,wave_cut2,wave_cut3,wave_cut4,wave_cut5))\nlumid=np.hstack((lumi_cut0,lumi_cut1,lumi_cut2,lumi_cut3,lumi_cut4,lumi_cut5))'

# %%
#np.savetxt('mira_codex_double.txt',np.column_stack([timed,waved,lumid]),fmt=('%.7e'),delimiter=' ')

# %%
data=np.array((data0,data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12,data13))

# %%
d=2.838e+20
#3.086e+20
#data[i][1]*(data[i][0]/(4.0*np.pi*3.086e+20*data[i][0]*10000))
wavelist=np.zeros((14,5000))
lumilist=np.zeros((14,5000))
for i in range(len(data)):
    hold1=data[i][1]*data[i][0]
    hold2=hold1/(4*np.pi*d**2)
    hold3=hold2*84.60
    lumi = hold3/(data[i][0]*10000)
    wave = data[i][0]*10000
    for j in range(5000):
        wavelist[i][j]=wave[j*3]
        lumilist[i][j]=lumi[j*3]

# %%
time=np.zeros((14,5000))
for k in range(14):
    for l in range(5000):
        time[k][l]=-90.0+30.0*k
        time[3][l]=0.0

# %%
time
# Out:
# array([[ -90.,  -90.,  -90., ...,  -90.,  -90.,  -90.],
#        [ -60.,  -60.,  -60., ...,  -60.,  -60.,  -60.],
#        [ -30.,  -30.,  -30., ...,  -30.,  -30.,  -30.],
#        ...,
#        [ 240.,  240.,  240., ...,  240.,  240.,  240.],
#        [ 270.,  270.,  270., ...,  270.,  270.,  270.],
#        [ 300.,  300.,  300., ...,  300.,  300.,  300.]])

# %%
lumilist
# Out:
# array([[  1.14337862e-11,   5.56518374e-12,   4.64422858e-12, ...,
#           3.38616940e-10,   3.31545529e-10,   3.09712756e-10],
#        [  9.56980905e-11,   6.37939904e-11,   4.87818697e-11, ...,
#           2.97843485e-10,   3.35925457e-10,   3.64695902e-10],
#        [  7.38126585e-10,   1.47020151e-09,   1.65216915e-09, ...,
#           2.52071562e-10,   2.73870900e-10,   3.41667844e-10],
#        ...,
#        [  4.23490589e-12,   1.79284509e-12,   1.44454048e-12, ...,
#           3.97662386e-10,   4.19068868e-10,   4.20665368e-10],
#        [  3.14393596e-11,   2.90195328e-11,   2.36908986e-11, ...,
#           4.22186641e-10,   4.42581727e-10,   4.90000302e-10],
#        [  3.26195998e-09,   1.27385702e-08,   2.65077609e-08, ...,
#           4.37867453e-10,   4.61405388e-10,   5.78175615e-10]])

# %%
timestack=np.concatenate((time))
wavestack=np.concatenate((wavelist))
lumistack=np.concatenate((lumilist))

# %%
np.savetxt('mira_codex_o54.txt',np.column_stack([timestack,wavestack,lumistack]),fmt=('%.7e'),delimiter=' ')

# %%
plt.plot(wavelist[0],lumilist[0],wavelist[1],lumilist[1],wavelist[2],lumilist[2])
plt.xlim(4000,20000)
# Out:
# (4000, 20000)

# %%
plt.plot(wavelist[3],lumilist[3],wavelist[4],lumilist[4],wavelist[5],lumilist[5],wavelist[6],lumilist[6])
plt.xlim(4000,20000)
# Out:
# (4000, 20000)

# %%
plt.plot(wavelist[7],lumilist[7],wavelist[8],lumilist[8],wavelist[9],lumilist[9])
plt.xlim(4000,20000)
# Out:
# (4000, 20000)

# %%
plt.plot(wavelist[10],lumilist[10],wavelist[11],lumilist[11],wavelist[12],lumilist[12],wavelist[13],lumilist[13])
plt.xlim(4000,20000)
# Out:
# (4000, 20000)
